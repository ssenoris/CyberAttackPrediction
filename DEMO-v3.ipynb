# %%
from trip_lib_v3 import *

# %%
trafico_normal = ['traficoperiodicos.csv','traficoweb.csv','trafico_mail2.csv','traficonormal2.csv','navegacion_normal.csv',
'prueba_trafico_normal_metasplotaible2.csv',
'trafico normal kali linux_meta y vm.csv',
'trafico normal y envio mail.csv',
'trafico_normal_conpin.csv',
'TRAFICO_NORMAL_DE_RED.csv',
'whireshark_navegacion_normal.csv']
trafico_ataques = ['Escaneo_Niktoataque.csv','Escaneo_Openvasataque.csv','Ataque Web Owasp Mutillidae  puerto 80.csv',
'meterpreter y ejecucion de comandos y shell linuxsuggester.csv','nmap owasp.csv',
'nmap_de_kali_a_meta.csv',
'nmap_de_kali_a_meta2.csv',
'nmap_de_meta_a_kali.csv',
'nmap_sV_metaisploitablev2.csv',
'Servidor_web_linux_con_contrasena_crackeada_TRAFICO_DE_RED.csv',
'Servidor_web_linux_sin_contrasena_TRAFICO_DE_RED.csv',
'Windows_con_contrasena_TRAFICO_DE _RED.csv',
'Windows_sin_contrasena_TRAFICO_DE_RED.csv']

# %%
prediccion(trafico_normal[5])
# Out:
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 45.0 %
# prueba_trafico_normal_metasplotaible2.csv  Maximo número de paquetes: 2156
# (<Figure size 576x432 with 1 Axes>, None)

# %%
prediccion(trafico_ataques[3])
# Out:
# b'Skipping line 2396: expected 1 fields, saw 3\nSkipping line 2432: expected 1 fields, saw 2\nSkipping line 3918: expected 1 fields, saw 3\nSkipping line 6489: expected 1 fields, saw 5\nSkipping line 7728: expected 1 fields, saw 2\nSkipping line 9449: expected 1 fields, saw 2\nSkipping line 9870: expected 1 fields, saw 2\nSkipping line 10093: expected 1 fields, saw 2\nSkipping line 10965: expected 1 fields, saw 2\nSkipping line 11972: expected 1 fields, saw 2\nSkipping line 12298: expected 1 fields, saw 2\nSkipping line 12472: expected 1 fields, saw 2\nSkipping line 12711: expected 1 fields, saw 2\nSkipping line 12916: expected 1 fields, saw 2\nSkipping line 12924: expected 1 fields, saw 2\nSkipping line 13082: expected 1 fields, saw 2\nSkipping line 13139: expected 1 fields, saw 2\nSkipping line 13294: expected 1 fields, saw 2\nSkipping line 13345: expected 1 fields, saw 2\nSkipping line 13520: expected 1 fields, saw 2\nSkipping line 13597: expected 1 fields, saw 2\nSkipping line 13792: expected 1 fields, saw 2\nSkipping line 15167: expected 1 fields, saw 3\n'
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 72.7 %
# b'Skipping line 2396: expected 1 fields, saw 3\nSkipping line 2432: expected 1 fields, saw 2\nSkipping line 3918: expected 1 fields, saw 3\nSkipping line 6489: expected 1 fields, saw 5\nSkipping line 7728: expected 1 fields, saw 2\nSkipping line 9449: expected 1 fields, saw 2\nSkipping line 9870: expected 1 fields, saw 2\nSkipping line 10093: expected 1 fields, saw 2\nSkipping line 10965: expected 1 fields, saw 2\nSkipping line 11972: expected 1
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 72.7 %
# b'Skipping line 34366: expected 1 fields, saw 2\n'
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 99.6 %
# b'Skipping line 6468: expected 1 fields, saw 3\nSkipping line 6540: expected 1 fields, saw 2\n'
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 79.7 %
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 97.2 %
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 99.8 %
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 89.5 %
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 94.9 %
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 94.5 %
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 93.4 %
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# Riesgo de ATAQUE 94.4 %

# %%
for i in trafico_normal:
    prediccion_(i)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# TRÁFICO NORMAL
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# TRÁFICO NORMAL
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# TRÁFICO NORMAL
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# TRÁFICO NORMAL
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# TRÁFICO NORMAL
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# TRÁFICO NORMAL
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# b'Skipping line 2396: expected 1 fields, saw 3\nSkipping line 2432: expected 1 fields, saw 2\nSkipping line 3918: expected 1 fields, saw 3\nSkipping line 6489: expected 1 fields, saw 5\nSkipping line 7728: expected 1 fields, saw 2\nSkipping line 9449: expected 1 fields, saw 2\nSkipping line 9870: expected 1 fields, saw 2\nSkipping line 10093: expected 1 fields, saw 2\nSkipping line 10965: expected 1 fields, saw 2\nSkipping line 11972: expected 1 fields, saw 2\nSkipping line 12298: expected 1 fields, saw 2\nSkipping line 12472: expected 1 fields, saw 2\nSkipping line 12711: expected 1 fields, saw 2\nSkipping line 12916: expected 1 fields, saw 2\nSkipping line 12924: expected 1 fields, saw 2\nSkipping line 13082: expected 1 fields, saw 2\nSkipping line 13139: expected 1 fields, saw 2\nSkipping line 13294: expected 1 fields, saw 2\nSkipping line 13345: expected 1 fields, saw 2\nSkipping line 13520: expected 1 fields, saw 2\nSkipping line 13597: expected 1 fields, saw 2\nSkipping line 13792: expected 1 fields, saw 2\nSkipping line 15167: expected 1 fields, saw 3\n'
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# TRÁFICO NORMAL
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# TRÁFICO NORMAL
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# TRÁFICO NORMAL
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# TRÁFICO NORMAL
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# <class 'pandas.core.frame.DataFrame'>
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'len_mean', 'len_std', 'len_min', 'len_max', 'tiempo_dec(s)', 't_uni',
#        'n_paquetes', 'n_paq_mean', 'n_paq_std', 'n_paq_min', 'n_paq_max',
#        'puerto_caliente', 'puerto_destino', 'escaner'],
#       dtype='object')
# TRÁFICO NORMAL
# C:\Users\34653\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
